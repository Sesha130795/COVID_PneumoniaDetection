# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import torchvision
from pathlib import Path
import PIL
from PIL import Image
from torchvision import transforms
import pandas as pd
import cv2
from tqdm.notebook import tqdm
import torchmetrics
from matplotlib.animation import FuncAnimation
import seaborn as sns

# %%
root_path = Path('Data')

# %%
train_path = Path('Data/train/COVID19/')
size_list = []
size_list = [np.asarray(Image.open(i)).shape for i in list(train_path.glob('*'))]
df = pd.DataFrame(size_list)
df.describe()
# Out:
#                  0            1           2
# count   460.000000   460.000000  336.000000
# mean   1309.558696  1439.773913    3.107143
# std     710.897474   805.120157    0.309756
# min     224.000000   224.000000    3.000000
# 25%     744.500000   886.500000    3.000000
# 50%    1024.000000  1050.500000    3.000000
# 75%    1971.000000  2000.000000    3.000000
# max    4757.000000  5623.000000    4.000000

# %%
def load(path):
    img = Image.open(path)
    img = PIL.ImageOps.grayscale(img) 
    img = cv2.resize(np.asarray(img), (224,224)).astype(np.float32)/255
    return img

# %%
size_list = [load(i).shape for i in list(train_path.glob('*'))]
df = pd.DataFrame(size_list)
df.describe()
# Out:
#            0      1
# count  460.0  460.0
# mean   224.0  224.0
# std      0.0    0.0
# min    224.0  224.0
# 25%    224.0  224.0
# 50%    224.0  224.0
# 75%    224.0  224.0
# max    224.0  224.0

# %%
def mean_std(root_path):
    sums, sum_squared = 0,0
    files = 0
    for path in tqdm(list(root_path.glob('*'))):
        for p in tqdm(list(path.glob('*'))):
            img = load(p)
            sums+= np.sum(img)/(img.shape[0]*img.shape[1])
            sum_squared+= np.sum(img**2)/(img.shape[0]*img.shape[1])
            files+=1
    print(files)
    mean = sums/files
    std = np.sqrt((sum_squared/files) - (mean**2))
    return mean, std
mean, std = mean_std(Path('Data/train'))
print(mean, std)
# Out:
# ...
#   0%|          | 0/3418 [00:00<?, ?it/s]
# 5144
# 0.4920391255128484 0.23256543325130302

# %%
mean, std = 0.4920391255128484, 0.23256543325130302

# %%
fig, ax = plt.subplots(1,2)
n = 0
for i in list(train_path.glob('*')):
    im = load(i)
    print(im.shape[0]*im.shape[1])
    ax[n].imshow(im, cmap = 'bone')
    n+=1
    if n==2:
        break
# Out:
# 50176
# 50176

# %%
class LungDataset(torch.utils.data.Dataset):
    def __init__(self, rootpath= None, train_transforms= None, val_transforms= None,num_train= None,seed_val= 42):
        super().__init__()
        self.train_transforms = train_transforms
        self.val_transforms = val_transforms
        self.num_train = num_train
        self.filenames = self.extractandshuffle(rootpath, seed_val)
            
    # @staticmethod
    def extractandshuffle(self, path, seed_val):
        files = []
        for paths in list(path.glob('*')):
            # print(paths)
            for classes in list(paths.glob('*')):
                # print(classes)
                for f in list(classes.glob('*')):
                    # print(f)
                    files.append((f, classes))
        np.random.seed(seed_val)
        np.random.shuffle(files)
        if self.train_transforms!=None:
            files = files[:self.num_train]
        else:
            files = files[self.num_train:]
        return files
        
    @staticmethod
    def get_label(path):
        labels =['COVID19', 'NORMAL', 'PNEUMONIA']
        return labels.index(list(path.parts)[-1])
        
    def load(self, path, transforms):
        img = Image.open(path)
        img = PIL.ImageOps.grayscale(img) 
        img = cv2.resize(np.asarray(img), (224,224)).astype(np.float32)/255
        img = transforms(img)
        return img

    def __len__(self):
        return len(self.filenames)

    def __getitem__(self, index):
        file_id = self.filenames[index][0]
        label = self.filenames[index][1]
        if self.train_transforms !=None:  #index <= self.num_train:
            # file_id = self.filenames[index][0]
            # label = self.filenames[index][1]
            return self.load(file_id, self.train_transforms), self.get_label(label)
        else:
            # file_id = self.filenames[index+num_train][0]
            # label = self.filenames[index+num_train][1]
            return self.load(file_id, self.val_transforms), self.get_label(label)

# %%
train_transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize(mean = mean, std =std), transforms.RandomAffine(degrees = (-5,5),
    translate=(0, 0.05),
    scale=(0.9, 1.1)), transforms.RandomRotation(10),transforms.RandomResizedCrop((224,224), #(0.9,1.1),
    scale=(0.35, 1)),
    transforms.RandomHorizontalFlip(p =0.3),
    transforms.ElasticTransform()])
val_transform =  transforms.Compose([transforms.ToTensor(), transforms.Normalize(mean = mean, std =std)])
# train_data = torchvision.datasets.DatasetFolder('Data/train', transform =train_transform, extensions='.jpg',loader = load)
# val_data = torchvision.datasets.DatasetFolder('Data/test', transform =val_transform, extensions='.jpg',loader = load)
# lung_ds = LungDataset(root_path, train_transform, val_transform, 5400, 42)
train_data = LungDataset(root_path, train_transform, None, 5144, 42)# [lung_ds[i] for i in range(5400)]
val_data = LungDataset(root_path, None, val_transform, 5144, 42)#[lung_ds[i] for i in range(5400, len(lung_ds))]

# %%
print(train_data.classes, val_data.classes)
train_data.classes = [0,1,2]
val_data.classes = [0,1,2]
print(train_data.classes, val_data.classes)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 print(train_data.classes, val_data.classes)
#       2 train_data.classes = [0,1,2]
#       3 val_data.classes = [0,1,2]
#
# AttributeError: 'LungDataset' object has no attribute 'classes'

# %%
# classes = np.array([i[1] for i in train_data])
# weights = np.unique(classes, return_counts=True)[1]
# weights = len(classes)/weights
# print(np.unique(classes, return_counts=True))
# print(weights)
class_weights =[]
for _, label in tqdm(train_data):
    if label == 0:
        class_weights.append(weights[0])
    elif label == 1:
        class_weights.append(weights[1])
    elif label == 2:
        class_weights.append(weights[2])
    else:
        print('Unknown class')
# Out:
#   0%|          | 0/5144 [00:00<?, ?it/s]

# %%
# np.save('class_weights_shuffled', class_weights)
# print(len(class_weights), len(classes))
class_weights =np.load('class_weights_shuffled.npy')
# df = pd.DataFrame({'Labels': classes,'Weights': class_weights})
# df.tail(-100)

# %%
# cw = np.load('class_weights_shuffled.npy')
# cw[cw ==10.69438669]=14
# cw[cw ==4.07606973]=5
# np.unique(cw, return_counts=True)

# %%
sampler = torch.utils.data.WeightedRandomSampler(weights = class_weights, num_samples=len(train_data))
train_loader = torch.utils.data.DataLoader(dataset = train_data, sampler = sampler, batch_size=10)
val_loader = torch.utils.data.DataLoader(dataset = val_data, shuffle = False, batch_size=10)

# %%
len(train_loader), len(val_loader)
# Out:
# (858, 215)

# %%
for b, (X,y) in enumerate(train_loader):
    fig, ax = plt.subplots(2,5, figsize =(10,10))
    k=0
    print(y)
    # for i in range(2):
    #     for j in range(5):
    #         ax[i][j].imshow(np.transpose(X[k].numpy(), (1,2,0)), cmap = 'bone')
    #         ax[i][j].set_title(y[k])
    #         k+=1
    break
# Out:
# tensor([2, 2, 2, 1, 1, 1, 2, 2, 1, 1])

# %%
from torchvision.models import resnet34, resnet18

# %%
model = resnet34(pretrained=True)
# Out:
# D:\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# D:\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# for param in list(model.children())[1:-1]:
#     param.requires_grad = False
for layer in list(model.parameters())[1:-1]:
    layer.requires_grad = False

# %%
class ResNet(torch.nn.Module):
    def __init__(self,in_channels, out_features):
        super().__init__()
        torch.manual_seed(4)
        self.model = resnet18(pretrained=True)
        self.model.conv1 = torch.nn.Conv2d(in_channels, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
        self.model.fc = torch.nn.Linear(in_features=512, out_features=out_features, bias=True)
        for name,param in list(self.model.named_parameters())[1:-5]:
            print(f'Setting {name} grad to False')
            param.requires_grad = False
    def forward(self, X):
        pred = self.model(X)
        return pred
        # return torch.nn.functional.softmax(pred, dim = 1)
new_model = ResNet(1,3)
new_model
# Out:
# Setting bn1.weight grad to False
# Setting bn1.bias grad to False
# Setting layer1.0.conv1.weight grad to False
# Setting layer1.0.bn1.weight grad to False
# Setting layer1.0.bn1.bias grad to False
# Setting layer1.0.conv2.weight grad to False
# Setting layer1.0.bn2.weight grad to False
# Setting layer1.0.bn2.bias grad to False
# Setting layer1.1.conv1.weight grad to False
# Setting layer1.1.bn1.weight grad to False
# Setting layer1.1.bn1.bias grad to False
# Setting layer1.1.conv2.weight grad to False
# Setting layer1.1.bn2.weight grad to False
# Setting layer1.1.bn2.bias grad to False
# Setting layer2.0.conv1.weight grad to False
# Setting layer2.0.bn1.weight grad to False
# Setting layer2.0.bn1.bias grad to False
# Setting layer2.0.conv2.weight grad to False
# Setting layer2.0.bn2.weight grad to False
# Setting layer2.0.bn2.bias grad to False
# Setting layer2.0.downsample.0.weight grad to False
# Setting layer2.0.downsample.1.weight grad to False
# ...

# %%
# for i, (name, p) in enumerate(list(new_model.named_parameters())):
#     print(i,name)

# %%
# for p in new_model.parameters():
#     print(p.requires_grad)

# %%
epochs = 20
criterion = torch.nn.CrossEntropyLoss()
num_layers = len(list(new_model.parameters()))
train_parameters_layers = [list(new_model.parameters())[0]]
train_parameters = [list(new_model.parameters())[i]for i in range(num_layers-5, num_layers)]
for p in train_parameters:
    train_parameters_layers.append(p)
optimizer = torch.optim.SGD(train_parameters_layers,lr=0.001, momentum=0.9, weight_decay=0.1)
# optimizer = torch.optim.Adam([list(new_model.parameters())[0],list(new_model.parameters())[-1]], lr = 0.001)
# scheduler = torch.optim.lr_scheduler.ExponentialLR(gamma = 0.1)
train_losses=[]
val_losses = []
Train_Accuracy= []
Val_Accuracy = []
Train_Loss_Epoch = []
device = ['cuda:0' if torch.cuda.is_available() == True else 'cpu']
new_model = new_model.to(device[0])
print(len(train_parameters_layers))
# Out:
# 6

# %%
for e in tqdm(range(epochs)):
    train_batch_corr = 0
    # train_loss = 0
    print('**************************Training Results*********************************')
    for b, (X_train, y_train) in tqdm(enumerate(train_loader)):
        pred = new_model(X_train.float().to(device[0]))
        loss= criterion(pred.cpu(), y_train)
        # train_loss+=loss.item()
        train_batch_corr+= torch.sum(torch.argmax(pred.cpu(), dim=1)==y_train).item()
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        if b % 200 ==0:
            print(f'Epoch,batch: {e,b} Loss:{loss.item()} Accuracy: {train_batch_corr/((b+1)*len(y_train))}')
            # print(f'Epoch, Batch: {e, b} , Accuracy: {train_batch_corr/((b+1)* len(y_train))}, End_Batch_Loss: {loss.item()}, Batch Loss: {train_loss/(b+1)}')

    Train_Accuracy.append(train_batch_corr/((b+1)* len(y_train)))
    train_losses.append(loss.item())
    # Train_Accuracy_Epoch.append(epoch_acc)
    # Train_Loss_Epoch.append(train_loss/(b+1))
    print('**************************Validation Results*********************************')
    with torch.no_grad():        
        val_batch_corr = 0
        val_loss = 0
        
        for b_t, (X_test, y_test) in tqdm(enumerate(val_loader)):
            val_pred = new_model(X_test.float().to(device[0]))
            vloss= criterion(val_pred.cpu(), y_test)
            # val_loss+=loss.item()
            val_batch_corr+= torch.sum(torch.argmax(val_pred.cpu(), dim=1)==y_test).item()
            if b_t % 50 ==0:
                
                print(f'Epoch,batch: {e,b_t} Loss:{vloss.item()} Accuracy: {val_batch_corr/((b_t+1)*len(y_test))}')
                # print(f'Epoch, Batch: {e, b_t}, Accuracy: {val_batch_corr/((b_t+1)* len(y_test))},End_Batch Loss: {vloss.item()},Batch Loss: {val_loss/(b_t+1)}')
    val_losses.append(vloss.item()) 
    Val_Accuracy.append(val_batch_corr/((b+1)*len(y_test)))
    plt.plot(range(e+1), Train_Accuracy)
    plt.plot(range(e+1), Val_Accuracy)
    plt.show()
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# **************************Training Results*********************************
# 0it [00:00, ?it/s]
# Epoch,batch: (0, 0) Loss:0.9951651692390442 Accuracy: 0.5
# Epoch,batch: (0, 200) Loss:0.4321500360965729 Accuracy: 0.6671641791044776
# Epoch,batch: (0, 400) Loss:0.7183576226234436 Accuracy: 0.7231920199501247
# **************************Validation Results*********************************
# 0it [00:00, ?it/s]
# Epoch,batch: (0, 0) Loss:1.2880829572677612 Accuracy: 0.4
# Epoch,batch: (0, 50) Loss:1.279521107673645 Accuracy: 0.5647058823529412
# Epoch,batch: (0, 100) Loss:1.3351002931594849 Accuracy: 0.5188118811881188
# **************************Training Results*********************************
# 0it [00:00, ?it/s]
# Epoch,batch: (1, 0) Loss:0.6740012168884277 Accuracy: 0.7
# Epoch,batch: (1, 200) Loss:0.39123234152793884 Accuracy: 0.8134328358208955
# Epoch,batch: (1, 400) Loss:0.40970316529273987 Accuracy: 0.8134663341645886
# ...

# %%
# plt.plot(range(epochs), Val_Accuracy)
torch.save(new_model.state_dict(), 'Shuffled_model_5_layers')
metrics_dict = {'Train_accuracy': Train_Accuracy, 'Val Accuracy': Val_Accuracy, 'Train_Loss': train_losses, 'Val_Loss':val_losses}
with open('Shuffled_model_5_layers_Metrics.txt', 'w') as f:
    f.write(str(metrics_dict))

# %%
plt.plot(range(epochs), Val_Accuracy)

# %%
# test_loader = torch.utils.data.DataLoader(dataset = val_data, shuffle = False, batch_size=10)
new_model.eval()
with torch.no_grad():
    preds = []
    labels = []
    for b,(X,y) in tqdm(enumerate(val_loader)):
        pred = new_model(X.to(device[0]))
        loss =criterion(pred.cpu(), torch.tensor(y))
        preds.append(pred)
        labels.append(y)
# Out:
# 0it [00:00, ?it/s]
# C:\Users\sesha\AppData\Local\Temp\ipykernel_18124\2324449109.py:8: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   loss =criterion(pred.cpu(), torch.tensor(y))

# %%
pred = [torch.argmax(i, axis =1).cpu() for i in preds]
corr = 0
for i in range(len(pred)):
    # print((pred[i].cpu() == labels[i]).numpy())
    corr+= np.sum((pred[i].cpu() == labels[i]).numpy())
print(corr/(len(pred)*10))
print(corr,len(labels)*10)
preds_1d = []
labels_1d =[]
for i in pred:
    for j in i:
        preds_1d.append(j)
                
for i in labels:
    for j in i:
        labels_1d.append(j)
cf_mat = torchmetrics.ConfusionMatrix(task= 'multiclass', num_classes =3)
Acc = torchmetrics.Accuracy(task= 'multiclass', num_classes =3)
Recall = torchmetrics.Recall(task= 'multiclass', num_classes =3)
F1 = torchmetrics.F1Score(task= 'multiclass', num_classes =3)
Precision = torchmetrics.Precision(task= 'multiclass', num_classes =3)


acc_score = Acc(torch.tensor((preds_1d)), torch.tensor(labels_1d))
f1_score = F1(torch.tensor((preds_1d)), torch.tensor(labels_1d))
precision_score =Precision(torch.tensor((preds_1d)), torch.tensor(labels_1d))
recall_score = Recall(torch.tensor((preds_1d)), torch.tensor(labels_1d))
cf=cf_mat(torch.tensor((preds_1d)), torch.tensor(labels_1d))
# print(cf)
sns.heatmap(cf, annot = True)
print(f'Acc:{acc_score}\nPrecision: {precision_score}\nRecall: {recall_score}\nF1_score: {f1_score}')
# Out:
# 0.7496124031007751
# 967 1290
# Acc:0.7507764101028442
# Precision: 0.7507764101028442
# Recall: 0.7507764101028442
# F1_score: 0.7507764101028442

# %%
for p in list(new_model.parameters()):
    print(p)
# Out:
# Parameter containing:
# tensor([[[[-0.2438, -0.2856, -0.2826,  ..., -0.1689, -0.1453, -0.0379],
#           [-0.1491, -0.2160, -0.1911,  ..., -0.0592, -0.0261, -0.1149],
#           [-0.1831, -0.0455, -0.0358,  ..., -0.0918, -0.0826, -0.0733],
#           ...,
#           [-0.1314, -0.2186, -0.1565,  ...,  0.1078,  0.0857,  0.1403],
#           [-0.2479, -0.0277,  0.0373,  ..., -0.0308, -0.1714, -0.0203],
#           [-0.1194, -0.1458, -0.1375,  ..., -0.0607, -0.1281, -0.0529]]],
#
#
#         [[[ 0.1992,  0.1987, -0.1187,  ...,  0.0388,  0.0832,  0.0717],
#           [ 0.1219,  0.2997,  0.2586,  ...,  0.1299,  0.1274,  0.0144],
#           [ 0.3172,  0.3661,  0.3888,  ...,  0.1905,  0.0280,  0.1446],
#           ...,
#           [ 0.0469, -0.0409, -0.0111,  ...,  0.1625,  0.0392,  0.2622],
#           [ 0.1219, -0.0451,  0.0724,  ..., -0.0166,  0.0444,  0.2112],
#           [ 0.1374,  0.1078,  0.0825,  ...,  0.0251,  0.2854,  0.0719]]],
#
#
# ...

# %%
# val_classes = np.array([i[1] for i in val_data])
print(np.unique(val_classes, return_counts =True))
# Out:
# (array([0, 1, 2]), array([ 95, 321, 872], dtype=int64))

# %%
model_1 = ResNet(1,3)
for p in list(model_1.parameters()):
    print(p)
# Out:
# Parameter containing:
# tensor([[[[-0.1272,  0.1034, -0.0301,  ..., -0.0329,  0.0407,  0.0138],
#           [ 0.0814, -0.0820, -0.0604,  ...,  0.0238, -0.0623,  0.0023],
#           [-0.1239, -0.0962, -0.0734,  ..., -0.0522,  0.1387, -0.0595],
#           ...,
#           [ 0.1132, -0.0011, -0.0110,  ...,  0.1283, -0.0047, -0.0175],
#           [ 0.0727, -0.1332,  0.0560,  ...,  0.0996,  0.1386, -0.0766],
#           [ 0.0690,  0.1208,  0.0038,  ...,  0.0551,  0.0295,  0.0142]]],
#
#
#         [[[-0.1110,  0.1118, -0.0518,  ...,  0.1256, -0.0351,  0.0162],
#           [-0.0222,  0.0673,  0.0853,  ..., -0.0288, -0.0600,  0.1055],
#           [ 0.0057,  0.1333, -0.0934,  ..., -0.1214,  0.0234,  0.0054],
#           ...,
#           [ 0.0646, -0.1053,  0.1040,  ..., -0.1051,  0.0799, -0.1420],
#           [ 0.0722, -0.1307, -0.0787,  ..., -0.0471,  0.0574,  0.1388],
#           [ 0.0673, -0.1039,  0.0587,  ..., -0.0061,  0.0286,  0.0506]]],
#
#
# ...

# %%
test_model =ResNet(1,3)
test_model.load_state_dict(torch.load('1st_model_5 layers'))
# Out:
# D:\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# D:\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %%
for p in list(test_model.parameters()):
    print(p)
# Out:
# Parameter containing:
# tensor([[[[-4.4600e-04, -4.6346e-03, -3.8839e-03,  ..., -4.9502e-03,
#            -3.4830e-03, -2.4601e-03],
#           [ 6.8978e-03,  3.1332e-03,  5.0739e-03,  ...,  7.2942e-03,
#             7.7697e-03,  9.3842e-03],
#           [ 9.3261e-03,  4.4320e-03,  6.9300e-03,  ...,  1.0210e-02,
#             1.1898e-02,  1.3964e-02],
#           ...,
#           [ 1.2879e-02,  6.9094e-03,  1.0099e-02,  ...,  5.7235e-03,
#             7.6178e-03,  1.0536e-02],
#           [ 1.5199e-02,  9.0595e-03,  1.0063e-02,  ...,  2.8304e-03,
#             3.0755e-03,  7.7313e-03],
#           [ 1.7538e-02,  8.6636e-03,  6.5595e-03,  ..., -1.2856e-03,
#            -1.0256e-03,  3.4441e-03]]],
#
#
#         [[[-2.5178e-02, -2.5213e-02, -2.0477e-02,  ..., -1.9313e-02,
#            -2.1630e-02, -1.9277e-02],
#           [-2.1463e-02, -1.9345e-02, -1.4859e-02,  ..., -1.4917e-02,
#            -1.6226e-02, -1.4768e-02],
# ...

# %%
a = np.arange(5000)
np.random.seed(101)
np.random.shuffle(a)
print(a)
# Out:
# [1718 2511  345 ... 1361 1547 4959]

# %%
b
